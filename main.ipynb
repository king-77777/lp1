# %%
# 导入必要的库
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.tree import DecisionTreeRegressor, plot_tree, export_graphviz
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np
# ==============================
# 第 1 部分：数据集描述与特征选择 (EDA)
# ==============================

# 加载数据集
data = pd.read_csv('life_expectancy_data.csv')

# 数据集基本信息
print("数据集基本信息：")
print(data.info())

# 查看前几行数据
print("\n数据集预览：")
print(data.head())

# 检查缺失值
missing_values = data.isnull().sum()
missing_values = missing_values[missing_values > 0].sort_values(ascending=False)
print("\n缺失值统计：\n", missing_values)

# 填充缺失值（使用中位数）
data.fillna(data.median(numeric_only=True), inplace=True)

# 编码分类变量
data['Status'] = data['Status'].map({'Developing': 0, 'Developed': 1})

# 描述性统计
print("\n描述性统计：")
print(data.describe())

# 目标变量分布
plt.figure(figsize=(10, 6))
sns.histplot(data['Life expectancy '], bins=30, kde=True, color='skyblue')
plt.title('预期寿命分布')
plt.xlabel('预期寿命')
plt.ylabel('频率')
plt.show()

# 删除非数值列
data_numeric = data.drop(columns=['Country', 'Year'])

# 查看特征与目标变量的相关性
correlation_matrix = data_numeric.corr()
correlation_with_target = correlation_matrix['Life expectancy '].sort_values(ascending=False)
print("\n与预期寿命相关性：\n", correlation_with_target)

# 可视化相关性矩阵
plt.figure(figsize=(16, 12))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('特征相关性矩阵')
plt.show()

# 根据相关性筛选特征
selected_features = correlation_with_target[abs(correlation_with_target) > 0.3].index.tolist()
selected_features.remove('Life expectancy ')

print("\n选择的特征：", selected_features)

# ==============================
# 第 2 部分：根据 EDA 结果构建流水线 (DVC)
# ==============================
# DVC 步骤：
# 1. 初始化 DVC：
#    dvc init
#
# 2. 创建 DVC 阶段：
# - 数据预处理阶段：
#    dvc run -n preprocess -d life_expectancy_data.csv -o processed_data.csv python preprocess.py
#
# - 特征选择阶段：
#    dvc run -n feature_selection -d processed_data.csv -o selected_features.csv python feature_selection.py
#
# - 模型训练阶段：
#    dvc run -n train_model -d selected_features.csv -o model.pkl python train_model.py
#
# - 模型评估阶段：
#    dvc run -n evaluate -d model.pkl -o metrics.json python evaluate.py
#
# 3. 查看 DVC 流水线图：
#    dvc dag

# ==============================
# 第 3 部分：线性回归模型实现
# ==============================

# 数据预处理：选择相关特征和目标变量
X = data[selected_features]
y = data['Life expectancy ']

# 数据标准化
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 拆分训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# 创建线性回归模型
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)

# 预测
y_pred = linear_model.predict(X_test)

# 模型评估
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"\n线性回归模型 - 均方误差 (MSE): {mse}")
print(f"线性回归模型 - R² 得分: {r2}")

# 查看权重（系数）
coefficients = pd.Series(linear_model.coef_, index=selected_features).sort_values(ascending=False)
print("\n线性回归模型 - 权重（系数）：\n", coefficients)

# 绘制预测值和真实值的对比图
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.5, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel("真实值 (预期寿命)")
plt.ylabel("预测值 (预期寿命)")
plt.title("线性回归模型预测结果")
plt.show()

# 显示特征的重要性
plt.figure(figsize=(12, 8))
coefficients.plot(kind='bar')
plt.title('线性回归模型 - 特征重要性 (系数)')
plt.show()

# ==============================
# 第 4 部分：决策树回归模型实现（只展示前2层）
# ==============================

# 创建并训练决策树模型（限制最大深度为 4，但只展示前2层）
tree_model = DecisionTreeRegressor(max_depth=4, random_state=42)
tree_model.fit(X_train, y_train)

# 模型预测与评估
y_pred_tree = tree_model.predict(X_test)
mse_tree = mean_squared_error(y_test, y_pred_tree)
r2_tree = r2_score(y_test, y_pred_tree)

print(f"\n决策树模型 - 均方误差 (MSE): {mse_tree:.2f}")
print(f"决策树模型 - R² 得分: {r2_tree:.2f}")

# 决策树结构图：仅展示第一层和其子层（max_depth 控制可视层数）
plt.figure(figsize=(20, 10))
plot_tree(tree_model,
          feature_names=selected_features,
          filled=True,
          rounded=True,
          fontsize=12,
          max_depth=3)  # 只展示第一个节点和其直接子节点
plt.title("决策树结构图(展示前2层)")
plt.show()

# ==============================
# 第 5 部分：CatBoost 回归模型实现
# ==============================

# 创建并训练 CatBoost 模型（不输出训练过程）
catboost_model = CatBoostRegressor(verbose=0, random_state=42)
catboost_model.fit(X_train, y_train)

# 预测与评估
y_pred_cb = catboost_model.predict(X_test)
mse_cb = mean_squared_error(y_test, y_pred_cb)
r2_cb = r2_score(y_test, y_pred_cb)

print(f"\nCatBoost 模型 - 均方误差 (MSE): {mse_cb:.2f}")
print(f"CatBoost 模型 - R² 得分: {r2_cb:.2f}")

# 获取特征重要性
feature_importance_cb = pd.Series(catboost_model.get_feature_importance(), index=selected_features).sort_values(ascending=False)
print("\nCatBoost 模型 - 特征重要性：\n", feature_importance_cb)

# 可视化特征重要性
plt.figure(figsize=(10, 6))
feature_importance_cb.plot(kind='bar', color='cornflowerblue')
plt.title('CatBoost 模型 - 特征重要性')
plt.ylabel('重要性')
plt.tight_layout()
plt.show()

# ==============================
# 第 6 部分：XGBoost 回归模型实现
# ==============================

# 创建并训练 XGBoost 模型
xgb_model = XGBRegressor(random_state=42, verbosity=0)
xgb_model.fit(X_train, y_train)

# 模型预测与评估
y_pred_xgb = xgb_model.predict(X_test)
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
r2_xgb = r2_score(y_test, y_pred_xgb)

print(f"\nXGBoost 模型 - 均方误差 (MSE): {mse_xgb:.2f}")
print(f"XGBoost 模型 - R² 得分: {r2_xgb:.2f}")

# 提取特征重要性
feature_importance_xgb = pd.Series(xgb_model.feature_importances_, index=selected_features).sort_values(ascending=False)
print("\nXGBoost 模型 - 特征重要性：\n", feature_importance_xgb)

# 可视化特征重要性
plt.figure(figsize=(10, 6))
feature_importance_xgb.plot(kind='bar', color='mediumseagreen')
plt.title('XGBoost 模型 - 特征重要性')
plt.ylabel('重要性')
plt.tight_layout()
plt.show()

# ==============================
# 第 7 部分：MLP 神经网络回归模型
# ==============================

# 创建神经网络模型（3 层，每层 64 个神经元）
mlp_model = MLPRegressor(hidden_layer_sizes=(64, 64, 64),
                         max_iter=500,
                         solver='adam',
                         activation='relu',
                         learning_rate='adaptive',
                         random_state=42,
                         verbose=True)  # 可以观察每轮 loss

# 拟合模型
mlp_model.fit(X_train, y_train)

# 预测与评估
y_pred_mlp = mlp_model.predict(X_test)
mse_mlp = mean_squared_error(y_test, y_pred_mlp)
r2_mlp = r2_score(y_test, y_pred_mlp)

print(f"\nMLP 神经网络 - MSE: {mse_mlp:.2f}")
print(f"MLP 神经网络 - R²: {r2_mlp:.2f}")

# ==============================
# 学习曲线（损失函数变化）
# ==============================
plt.figure(figsize=(10, 6))
plt.plot(mlp_model.loss_curve_, color='purple')
plt.title("MLP 训练过程中的损失曲线")
plt.xlabel("迭代次数")
plt.ylabel("损失值 (Loss)")
plt.grid(True)
plt.tight_layout()
plt.show()

# ==============================
# 权重直方图（每一层）
# ==============================
for i, weights in enumerate(mlp_model.coefs_):
    plt.figure(figsize=(8, 4))
    plt.hist(weights.ravel(), bins=30, color='orange', alpha=0.7)
    plt.title(f"第 {i+1} 层的权重直方图")
    plt.xlabel("权重值")
    plt.ylabel("频率")
    plt.tight_layout()
    plt.show()

# ==============================
# 完成
# ==============================
# Out:
# 数据集基本信息：
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2732 entries, 0 to 2731
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2732 non-null   object
#  1   Year                             2732 non-null   int64
#  2   Status                           2732 non-null   object
#  3   Life expectancy                  2724 non-null   float64
#  4   Adult Mortality                  2724 non-null   float64
#  5   infant deaths                    2732 non-null   int64
#  6   Alcohol                          2547 non-null   float64
#  7   percentage expenditure           2732 non-null   float64
#  8   Hepatitis B                      2207 non-null   float64
#  9   Measles                          2732 non-null   int64
#  10   BMI                             2699 non-null   float64
# ...

# %%
# !dvc dag --dot > graph.dot
# !dot -Tpng graph.dot -o pipeline.png

from IPython.display import Image
Image("pipeline.png")

# %%
import os
import shutil
from IPython.display import Image, display

# Step 1：生成 .dot 文件
os.system("dvc dag --dot > graph.dot")

# Step 2：检查 Graphviz 是否已安装
dot_path = shutil.which("dot")
if dot_path:
    print(f"✅ Graphviz 已安装，路径：{dot_path}")
    
    # Step 3：生成 PNG 图片
    result = os.system("dot -Tpng graph.dot -o pipeline.png")
    
    if result == 0 and os.path.exists("pipeline.png"):
        print("✅ DVC 流程图 pipeline.png 已生成！")
        display(Image("pipeline.png"))
    else:
        print("⚠️ 生成 pipeline.png 失败，请确认 dot 命令可用")
else:
    print("❌ 未检测到 Graphviz 的 dot 命令")
    print("➡️ 请前往 https://graphviz.gitlab.io/download/ 下载并安装 Graphviz")
    print("➡️ 安装后请将 Graphviz 的 bin 目录加入系统环境变量 PATH")
# Out:
# ✅ Graphviz 已安装，路径：C:\Program Files\Graphviz\bin\dot.EXE
# ✅ DVC 流程图 pipeline.png 已生成！
